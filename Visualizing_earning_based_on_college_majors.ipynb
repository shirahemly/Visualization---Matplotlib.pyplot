# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
recent_grads = pd.read_csv('recent-grads.csv')
recent_grads.iloc[:1]
recent_grads.head()
recent_grads.tail()
recent_grads.describe()
# Out:
#              Rank   Major_code          Total            Men          Women  \
# count  173.000000   173.000000     172.000000     172.000000     172.000000
# mean    87.000000  3879.815029   39370.081395   16723.406977   22646.674419
# std     50.084928  1687.753140   63483.491009   28122.433474   41057.330740
# min      1.000000  1100.000000     124.000000     119.000000       0.000000
# 25%     44.000000  2403.000000    4549.750000    2177.500000    1778.250000
# 50%     87.000000  3608.000000   15104.000000    5434.000000    8386.500000
# 75%    130.000000  5503.000000   38909.750000   14631.000000   22553.750000
# max    173.000000  6403.000000  393735.000000  173809.000000  307087.000000
#
#        ShareWomen  Sample_size       Employed      Full_time      Part_time  \
# count  172.000000   173.000000     173.000000     173.000000     173.000000
# mean     0.522223   356.080925   31192.763006   26029.306358    8832.398844
# ...

# %%
raw_data_count = recent_grads.shape[0]
raw_data_count
# Out:
# 173

# %%
recent_grads = recent_grads.dropna()
#Drop rows with missing values

# %%
cleaned_data_count = recent_grads.shape[0]
cleaned_data_count
# Out:
# 172

# %%
recent_grads.plot(x='Sample_size', y='Median', kind='scatter', title='Sample_size and Median', figsize=(5,10))

# %%
recent_grads.plot(x='Sample_size', y='Unemployment_rate', kind='scatter', title='Sample_size and Unemployment_rate')

# %%
recent_grads.plot(x='Full_time', y='Median', kind='scatter', title='Full_time and Median')

# %%
recent_grads.plot(x='ShareWomen', y='Unemployment_rate', kind='scatter', title='ShareWomen and Unemployment_rate')

# %%
recent_grads.plot(x='Men', y='Median', kind='scatter', title='Men and Median')

# %%
recent_grads.plot(x='Women', y='Median', kind='scatter', title='Women and Median')

# %% [markdown]
# - Do students in more popular majors make more money?
# No
# - Do students that majored in subjects that were majority female make more money?
# No
# - Is there any link between the number of full-time employees and median salary?
# Highest salaries were displayed in majors with the smaller numbers of full-time employees, with weak correlation

# %%
cols = ['Sample_size', 'Median', 'Employed', 'Full_time', 'ShareWomen', 'Unemployment_rate', 'Men', 'Women']
fig = plt.figure(figsize=(10,45))

for i in range(1,8):
    ax = fig.add_subplot(8,1,i)
    ax = recent_grads[cols[i]].plot(kind='hist', rot=30)
    ax.set_title(cols[i])

# %%
recent_grads['ShareWomen'].hist(normed=True)

# %% [markdown]
# - What percent of majors are predominantly male? Predominantly female?
# predominantly male - Around 0.42
# Predominantly female - Around 0.58
#
# - What's the most common median salary range?
# 30000 - 40000

# %%
from pandas.plotting import scatter_matrix

scatter_matrix(recent_grads[['Sample_size', 'Median']])
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fda9888de80>,
# ...
#       dtype=object)

# %%
scatter_matrix(recent_grads[['Sample_size', 'Median', 'Unemployment_rate']], figsize=(10,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fda92cb2160>,
# ...
#       dtype=object)

# %%
recent_grads[:10].plot.bar(x='Major', y='ShareWomen', legend=False)

# %%
recent_grads[163:].plot.bar(x='Major', y='ShareWomen', legend=False)

# %%
recent_grads[163:].plot.bar(x='Major', y='ShareWomen', legend=False)

# %%
recent_grads[163:].plot.bar(x='Major', y='ShareWomen', legend=False)

# %%
recent_grads[:10].plot.bar(x='Major', y='Unemployment_rate', legend=False)

# %%
recent_grads[162:].plot.bar(x='Major', y='Unemployment_rate', legend=False)
